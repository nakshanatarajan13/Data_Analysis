# %%
import pandas as pd
import numpy as np
import os 
print (os.getcwd())
# Out:
# C:\Users\AI_DS-B1\Desktop

# %%
data=pd.read_csv("Ex 2 - Engineering_graduate_salary.csv")

# %%
data.head()
# Out:
#        ID Gender         DOB  10percentage                       10board  \
# 0  604399      f  22-10-1990         87.80                          cbse
# 1  988334      m  15-05-1990         57.00                          cbse
# 2  301647      m  21-08-1989         77.33  maharashtra state board,pune
# 3  582313      m  04-05-1991         84.30                          cbse
# 4  339001      f  30-10-1990         82.00                          cbse
#
#    12graduation  12percentage                    12board  CollegeID  \
# 0          2009         84.00                       cbse       6920
# 1          2010         64.50                       cbse       6624
# 2          2007         85.17  amravati divisional board       9084
# 3          2009         86.00                       cbse       8195
# 4          2008         75.00                       cbse       4889
#
#    CollegeTier  ... CollegeCityID CollegeCityTier   CollegeState  \
# ...

# %%
duplicate=data["12board"].duplicated()

# %%
print("The duplicated values returns true")
print(duplicate)
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 2993     True
# 2994     True
# 2995    False
# 2996    False
# 2997     True
# Name: 12board, Length: 2998, dtype: bool

# %%
count=data["12board"].duplicated().sum()

# %%
print("Count of duplicated values")
print(count)
# Out:
# Count of duplicated values
# 2721

# %%
drop=data["12board"].drop_duplicates()
print(drop)
# Out:
# 0                                             cbse
# 2                        amravati divisional board
# 6                                      state board
# 12                                 all india board
# 15                                               0
#                            ...
# 2976    himachal pradesh board of school education
# 2981                                          dpue
# 2990              board of intermeadiate education
# 2995                                         bsemp
# 2996                     karnataka education board
# Name: 12board, Length: 277, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2998 non-null   int64
#  1   Gender               2998 non-null   object
#  2   DOB                  2998 non-null   object
#  3   10percentage         2749 non-null   float64
#  4   10board              2998 non-null   object
#  5   12graduation         2998 non-null   int64
#  6   12percentage         2998 non-null   float64
#  7   12board              2998 non-null   object
#  8   CollegeID            2998 non-null   int64
#  9   CollegeTier          2998 non-null   int64
#  10  Degree               2998 non-null   object
#  11  Specialization       2998 non-null   object
#  12  collegeGPA           2732 non-null   float64
#  13  CollegeCityID        2998 non-null   int64
#  14  CollegeCityTier      2998 non-null   int64
# ...

# %%
null1=data["10percentage"].isna()
count1=data["10percentage"].isna().sum()
print(null1)
print(count1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2993    False
# 2994    False
# 2995    False
# 2996    False
# 2997    False
# Name: 10percentage, Length: 2998, dtype: bool
# 249

# %%
import numpy as np
data["10percentage"].fillna(np.mean(data["10percentage"]),inplace=True)
data.info
# Out:
# <bound method DataFrame.info of           ID Gender         DOB  10percentage                       10board  \
# 0     604399      f  22-10-1990         87.80                          cbse
# 1     988334      m  15-05-1990         57.00                          cbse
# 2     301647      m  21-08-1989         77.33  maharashtra state board,pune
# 3     582313      m  04-05-1991         84.30                          cbse
# 4     339001      f  30-10-1990         82.00                          cbse
# ...      ...    ...         ...           ...                           ...
# 2993  103174      f  17-04-1989         75.00                             0
# 2994  352811      f  22-07-1991         84.00                   state board
# 2995  287070      m  24-11-1988         91.40                         bsemp
# 2996  317336      m  25-08-1988         88.64     karnataka education board
# 2997  993701      m  27-05-1992         77.00                   state board
#
# ...

# %%
count1=data["10percentage"].isna().sum()
print(count1)
# Out:
# 0

# %%
 import seaborn as sns
 import matplotlib.pyplot as plt
plt.figure(figsize=(30,15))
sns.heatmap(data.corr(),annot=True,linewidth=0.5,cmap="coolwarm")
# Out:
# <AxesSubplot:>
